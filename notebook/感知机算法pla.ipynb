# %% [markdown]
# # 感知机算法实现
# - TODO (模型,策略,算法)

# %%
import numpy as np

import sys
sys.path.append('/home/hadoop/deeplearning/coconut/')

from algorithms import pla
from data import genLinearSeparableData
from utils.plot import plotData
# %matplotlib inline

# %% [markdown]
# ## 生成数据及训练

# %%
W = np.random.rand(3) * 10
dataset = genLinearSeparableData(W, 50) #生成数据

w = pla(dataset)  # 训练

# %% [markdown]
# ## 画图

# %%
plotData(dataset, w)
