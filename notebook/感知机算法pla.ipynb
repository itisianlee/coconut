# %% [markdown]
# # 感知机算法实现
# - TODO (模型,策略,算法)
# - 原始形式实现
# - 对偶形式实现

# %%
import numpy as np

import sys
sys.path.append('/home/hadoop/deeplearning/coconut/')

from algorithms import pla, plaDualForm
from data import genLinearSeparableData
from utils.plot import plotData
# %matplotlib inline

# %% [markdown]
# ## 生成数据

# %%
W = np.random.rand(3) * 10
dataset = genLinearSeparableData(W, 20) #生成数据

# %% [markdown]
# ## 原始形式训练

# %%
w = pla(dataset)  # 训练

# %% [markdown]
# ## 画图

# %%
plotData(dataset, w)

# %% [markdown]
# ## 对偶形式训练

# %%
w = plaDualForm(dataset)

# %%
plotData(dataset, w)
